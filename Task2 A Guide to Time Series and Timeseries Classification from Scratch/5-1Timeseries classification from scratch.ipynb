# %% [markdown]
# # Timeseries classification from scratch
#
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Date created:** 2020/07/21<br>
# **Last modified:** 2021/07/16<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
# For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
x_train  #(3601, 500)
# Out:
# array([[-0.79717168, -0.66439208, -0.37301463, ..., -0.66439208,
#         -1.0737958 , -1.5643427 ],
#        [ 0.80485472,  0.63462859,  0.37347448, ..., -0.71488505,
#         -0.56044294, -0.31908642],
#        [ 0.7279851 ,  0.11128392, -0.49912439, ...,  0.39446303,
#          0.33940042,  0.25539062],
#        ...,
#        [-0.57005428, -0.33316523, -0.29351853, ..., -1.3937145 ,
#         -0.94273327, -0.27072168],
#        [ 2.0067321 ,  2.0791499 ,  2.0220362 , ..., -0.43214504,
#         -0.44123126, -0.28070891],
#        [-0.12524091, -0.32536268, -0.48823697, ...,  0.55576053,
#          0.57445102,  0.57311598]])

# %%
y_train#(3601,)
# Out:
# array([-1,  1, -1, ..., -1,  1, -1])

# %%
y_train.shape
# Out:
# (3601,)

# %%
x_train[0].shape  #x_train
# Out:
# (500,)

# %%
x_train[0][0]  #-0.79717168
# Out:
# -0.79717168

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))
classes
# Out:
# array([-1,  1])

# %%
for c in classes:
    c_x_train = np.array(x_train[y_train == c])
c_x_train
c_x_train[0]
label="class " + str(c)
label
# Out:
# 'class 1'

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Train the model

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 90/90 [==============================] - 8s 80ms/step - loss: 0.5560 - sparse_categorical_accuracy: 0.7028 - val_loss: 0.8329 - val_sparse_categorical_accuracy: 0.4674
# Epoch 2/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.4662 - sparse_categorical_accuracy: 0.7628 - val_loss: 1.1696 - val_sparse_categorical_accuracy: 0.4674
# Epoch 3/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.4294 - sparse_categorical_accuracy: 0.7851 - val_loss: 1.1733 - val_sparse_categorical_accuracy: 0.4674
# Epoch 4/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.4303 - sparse_categorical_accuracy: 0.7788 - val_loss: 0.8288 - val_sparse_categorical_accuracy: 0.4674
# Epoch 5/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.4211 - sparse_categorical_accuracy: 0.7847 - val_loss: 0.5827 - val_sparse_categorical_accuracy: 0.6616
# Epoch 6/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.4096 - sparse_categorical_accuracy: 0.7948 - val_loss: 0.4359 - val_sparse_categorical_accuracy: 0.7670
# Epoch 7/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3971 - sparse_categorical_accuracy: 0.8038 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.6907
# Epoch 8/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3921 - sparse_categorical_accuracy: 0.8104 - val_loss: 1.3164 - val_sparse_categorical_accuracy: 0.5340
# Epoch 9/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3834 - sparse_categorical_accuracy: 0.8177 - val_loss: 0.6301 - val_sparse_categorical_accuracy: 0.6408
# Epoch 10/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3765 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.5652 - val_sparse_categorical_accuracy: 0.7074
# Epoch 11/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3657 - sparse_categorical_accuracy: 0.8233 - val_loss: 0.5800 - val_sparse_categorical_accuracy: 0.7254
# Epoch 12/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3689 - sparse_categorical_accuracy: 0.8233 - val_loss: 0.7187 - val_sparse_categorical_accuracy: 0.7046
# Epoch 13/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3533 - sparse_categorical_accuracy: 0.8340 - val_loss: 2.1504 - val_sparse_categorical_accuracy: 0.5326
# Epoch 14/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.3333 - sparse_categorical_accuracy: 0.8510 - val_loss: 1.8377 - val_sparse_categorical_accuracy: 0.5326
# Epoch 15/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3235 - sparse_categorical_accuracy: 0.8587 - val_loss: 2.1717 - val_sparse_categorical_accuracy: 0.5326
# Epoch 16/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.3296 - sparse_categorical_accuracy: 0.8510 - val_loss: 2.3569 - val_sparse_categorical_accuracy: 0.5326
# Epoch 17/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3313 - sparse_categorical_accuracy: 0.8503 - val_loss: 2.3345 - val_sparse_categorical_accuracy: 0.5326
# Epoch 18/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.8708 - val_loss: 1.8512 - val_sparse_categorical_accuracy: 0.5326
# Epoch 19/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3047 - sparse_categorical_accuracy: 0.8642 - val_loss: 4.6251 - val_sparse_categorical_accuracy: 0.4785
# Epoch 20/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.3183 - sparse_categorical_accuracy: 0.8625 - val_loss: 1.7434 - val_sparse_categorical_accuracy: 0.6796
# Epoch 21/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.2882 - sparse_categorical_accuracy: 0.8816 - val_loss: 6.1052 - val_sparse_categorical_accuracy: 0.4674
# Epoch 22/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.8733 - val_loss: 3.4799 - val_sparse_categorical_accuracy: 0.4938
# Epoch 23/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2978 - sparse_categorical_accuracy: 0.8663 - val_loss: 1.5549 - val_sparse_categorical_accuracy: 0.6394
# Epoch 24/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2864 - sparse_categorical_accuracy: 0.8792 - val_loss: 1.2448 - val_sparse_categorical_accuracy: 0.5631
# Epoch 25/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2775 - sparse_categorical_accuracy: 0.8813 - val_loss: 2.2854 - val_sparse_categorical_accuracy: 0.5326
# Epoch 26/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.8868 - val_loss: 0.3594 - val_sparse_categorical_accuracy: 0.8405
# Epoch 27/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.8924 - val_loss: 3.9289 - val_sparse_categorical_accuracy: 0.5326
# Epoch 28/500
# 90/90 [==============================] - 7s 76ms/step - loss: 0.2736 - sparse_categorical_accuracy: 0.8778 - val_loss: 2.1865 - val_sparse_categorical_accuracy: 0.5368
# Epoch 29/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2666 - sparse_categorical_accuracy: 0.8917 - val_loss: 3.4848 - val_sparse_categorical_accuracy: 0.5326
# Epoch 30/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.8892 - val_loss: 1.1255 - val_sparse_categorical_accuracy: 0.5908
# Epoch 31/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2586 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.4166 - val_sparse_categorical_accuracy: 0.7712
# Epoch 32/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2763 - sparse_categorical_accuracy: 0.8840 - val_loss: 1.7154 - val_sparse_categorical_accuracy: 0.5021
# Epoch 33/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2549 - sparse_categorical_accuracy: 0.8955 - val_loss: 2.0564 - val_sparse_categorical_accuracy: 0.5270
# Epoch 34/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2762 - sparse_categorical_accuracy: 0.8726 - val_loss: 1.0963 - val_sparse_categorical_accuracy: 0.5908
# Epoch 35/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2531 - sparse_categorical_accuracy: 0.8892 - val_loss: 0.3681 - val_sparse_categorical_accuracy: 0.8363
# Epoch 36/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2550 - sparse_categorical_accuracy: 0.8955 - val_loss: 4.3612 - val_sparse_categorical_accuracy: 0.5326
# Epoch 37/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2523 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.2684 - val_sparse_categorical_accuracy: 0.8946
# Epoch 38/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2526 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.6815 - val_sparse_categorical_accuracy: 0.7087
# Epoch 39/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2446 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.8677 - val_sparse_categorical_accuracy: 0.7101
# Epoch 40/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9024 - val_loss: 3.3182 - val_sparse_categorical_accuracy: 0.5160
# Epoch 41/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2352 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.5905 - val_sparse_categorical_accuracy: 0.6768
# Epoch 42/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2362 - sparse_categorical_accuracy: 0.9028 - val_loss: 5.6014 - val_sparse_categorical_accuracy: 0.4757
# Epoch 43/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2472 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.8713 - val_sparse_categorical_accuracy: 0.6949
# Epoch 44/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2318 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.6894 - val_sparse_categorical_accuracy: 0.7351
# Epoch 45/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2417 - sparse_categorical_accuracy: 0.8983 - val_loss: 2.1279 - val_sparse_categorical_accuracy: 0.5381
# Epoch 46/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.2354 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.5265 - val_sparse_categorical_accuracy: 0.7642
# Epoch 47/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2375 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.7804 - val_sparse_categorical_accuracy: 0.7004
# Epoch 48/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2219 - sparse_categorical_accuracy: 0.9080 - val_loss: 1.0305 - val_sparse_categorical_accuracy: 0.6200
# Epoch 49/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2216 - sparse_categorical_accuracy: 0.9069 - val_loss: 1.3793 - val_sparse_categorical_accuracy: 0.6602
# Epoch 50/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2220 - sparse_categorical_accuracy: 0.9135 - val_loss: 1.8633 - val_sparse_categorical_accuracy: 0.5659
# Epoch 51/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2245 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.2712 - val_sparse_categorical_accuracy: 0.6921
# Epoch 52/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9080 - val_loss: 2.7087 - val_sparse_categorical_accuracy: 0.5298
# Epoch 53/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2263 - sparse_categorical_accuracy: 0.9024 - val_loss: 0.3535 - val_sparse_categorical_accuracy: 0.8433
# Epoch 54/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2274 - sparse_categorical_accuracy: 0.9097 - val_loss: 4.6016 - val_sparse_categorical_accuracy: 0.6172
# Epoch 55/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.5868 - val_sparse_categorical_accuracy: 0.7628
# Epoch 56/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2210 - sparse_categorical_accuracy: 0.9073 - val_loss: 4.5859 - val_sparse_categorical_accuracy: 0.5340
# Epoch 57/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2132 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.2291 - val_sparse_categorical_accuracy: 0.9182
# Epoch 58/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2185 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.2352 - val_sparse_categorical_accuracy: 0.5895
# Epoch 59/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2155 - sparse_categorical_accuracy: 0.9094 - val_loss: 2.1611 - val_sparse_categorical_accuracy: 0.5589
# Epoch 60/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2057 - sparse_categorical_accuracy: 0.9163 - val_loss: 2.4566 - val_sparse_categorical_accuracy: 0.6921
# Epoch 61/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2003 - sparse_categorical_accuracy: 0.9167 - val_loss: 1.5067 - val_sparse_categorical_accuracy: 0.5506
# Epoch 62/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1960 - sparse_categorical_accuracy: 0.9212 - val_loss: 2.1944 - val_sparse_categorical_accuracy: 0.7129
# Epoch 63/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.1974 - sparse_categorical_accuracy: 0.9222 - val_loss: 6.3341 - val_sparse_categorical_accuracy: 0.5104
# Epoch 64/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1989 - sparse_categorical_accuracy: 0.9243 - val_loss: 3.4763 - val_sparse_categorical_accuracy: 0.5187
# Epoch 65/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9125 - val_loss: 1.1542 - val_sparse_categorical_accuracy: 0.6200
# Epoch 66/500
# 90/90 [==============================] - 7s 77ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9194 - val_loss: 2.0864 - val_sparse_categorical_accuracy: 0.6699
# Epoch 67/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9295 - val_loss: 4.1631 - val_sparse_categorical_accuracy: 0.4827
# Epoch 68/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1855 - sparse_categorical_accuracy: 0.9292 - val_loss: 4.2155 - val_sparse_categorical_accuracy: 0.4757
# Epoch 69/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1760 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.7163 - val_sparse_categorical_accuracy: 0.7517
# Epoch 70/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1901 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.4600 - val_sparse_categorical_accuracy: 0.8044
# Epoch 71/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1709 - sparse_categorical_accuracy: 0.9354 - val_loss: 2.6879 - val_sparse_categorical_accuracy: 0.5257
# Epoch 72/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1618 - sparse_categorical_accuracy: 0.9465 - val_loss: 5.2679 - val_sparse_categorical_accuracy: 0.4757
# Epoch 73/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9458 - val_loss: 2.8782 - val_sparse_categorical_accuracy: 0.6117
# Epoch 74/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.5126 - val_sparse_categorical_accuracy: 0.7795
# Epoch 75/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1467 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.2547 - val_sparse_categorical_accuracy: 0.8890
# Epoch 76/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.1620 - sparse_categorical_accuracy: 0.9389 - val_loss: 2.7179 - val_sparse_categorical_accuracy: 0.5076
# Epoch 77/500
# 90/90 [==============================] - 8s 89ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9556 - val_loss: 2.7724 - val_sparse_categorical_accuracy: 0.5395
# Epoch 78/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9573 - val_loss: 2.8868 - val_sparse_categorical_accuracy: 0.5215
# Epoch 79/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1231 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.7823 - val_sparse_categorical_accuracy: 0.7171
# Epoch 80/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1179 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.2626 - val_sparse_categorical_accuracy: 0.9057
# Epoch 81/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.4798 - val_sparse_categorical_accuracy: 0.6963
# Epoch 82/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1151 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.1457 - val_sparse_categorical_accuracy: 0.9376
# Epoch 83/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.1369 - val_sparse_categorical_accuracy: 0.9445
# Epoch 84/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.2980 - val_sparse_categorical_accuracy: 0.9015
# Epoch 85/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.5553 - val_sparse_categorical_accuracy: 0.7836
# Epoch 86/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1223 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.2723 - val_sparse_categorical_accuracy: 0.8890
# Epoch 87/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.1108 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.2130 - val_sparse_categorical_accuracy: 0.9126
# Epoch 88/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1075 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.1291 - val_sparse_categorical_accuracy: 0.9542
# Epoch 89/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1516 - val_sparse_categorical_accuracy: 0.9404
# Epoch 90/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.5755 - val_sparse_categorical_accuracy: 0.7628
# Epoch 91/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1117 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.1967 - val_sparse_categorical_accuracy: 0.9196
# Epoch 92/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0999 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1720 - val_sparse_categorical_accuracy: 0.9320
# Epoch 93/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9459
# Epoch 94/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0966 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.2177 - val_sparse_categorical_accuracy: 0.9140
# Epoch 95/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.1078 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.6479 - val_sparse_categorical_accuracy: 0.7698
# Epoch 96/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1116 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.9035 - val_sparse_categorical_accuracy: 0.6214
# Epoch 97/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1033 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.8269 - val_sparse_categorical_accuracy: 0.7032
# Epoch 98/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0961 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.4597 - val_sparse_categorical_accuracy: 0.7920
# Epoch 99/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0958 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.4556 - val_sparse_categorical_accuracy: 0.8211
# Epoch 100/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1110 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9570
# Epoch 101/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0998 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1242 - val_sparse_categorical_accuracy: 0.9556
# Epoch 102/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0969 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3695 - val_sparse_categorical_accuracy: 0.8350
# Epoch 103/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.1025 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.3579 - val_sparse_categorical_accuracy: 0.8474
# Epoch 104/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.4654 - val_sparse_categorical_accuracy: 0.8169
# Epoch 105/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.7545
# Epoch 106/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0937 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9598
# Epoch 107/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0942 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.2724 - val_sparse_categorical_accuracy: 0.9112
# Epoch 108/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0946 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.4669 - val_sparse_categorical_accuracy: 0.8197
# Epoch 109/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0870 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.3183 - val_sparse_categorical_accuracy: 0.8835
# Epoch 110/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0940 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.4681 - val_sparse_categorical_accuracy: 0.8211
# Epoch 111/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0910 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.1201 - val_sparse_categorical_accuracy: 0.9528
# Epoch 112/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0986 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.4761 - val_sparse_categorical_accuracy: 0.8031
# Epoch 113/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9694 - val_loss: 1.1600 - val_sparse_categorical_accuracy: 0.6463
# Epoch 114/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0977 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8585
# Epoch 115/500
# 90/90 [==============================] - 7s 78ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9705 - val_loss: 1.6683 - val_sparse_categorical_accuracy: 0.5576
# Epoch 116/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0963 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.9781 - val_sparse_categorical_accuracy: 0.6796
# Epoch 117/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.4480 - val_sparse_categorical_accuracy: 0.8211
# Epoch 118/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0895 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.4014 - val_sparse_categorical_accuracy: 0.8474
# Epoch 119/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0992 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.5671 - val_sparse_categorical_accuracy: 0.7878
# Epoch 120/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1388 - val_sparse_categorical_accuracy: 0.9528
# Epoch 121/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.2408 - val_sparse_categorical_accuracy: 0.9196
# Epoch 122/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1314 - val_sparse_categorical_accuracy: 0.9584
# Epoch 123/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1628 - val_sparse_categorical_accuracy: 0.9348
# Epoch 124/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1180 - val_sparse_categorical_accuracy: 0.9653
# Epoch 125/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0832 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1257 - val_sparse_categorical_accuracy: 0.9626
# Epoch 126/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.1242 - val_sparse_categorical_accuracy: 0.9598
# Epoch 127/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1524 - val_sparse_categorical_accuracy: 0.9528
# Epoch 128/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1101 - val_sparse_categorical_accuracy: 0.9653
# Epoch 129/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0851 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1763 - val_sparse_categorical_accuracy: 0.9376
# Epoch 130/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1212 - val_sparse_categorical_accuracy: 0.9584
# Epoch 131/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1200 - val_sparse_categorical_accuracy: 0.9528
# Epoch 132/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0763 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1440 - val_sparse_categorical_accuracy: 0.9542
# Epoch 133/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.8779
# Epoch 134/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1171 - val_sparse_categorical_accuracy: 0.9639
# Epoch 135/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1280 - val_sparse_categorical_accuracy: 0.9528
# Epoch 136/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1213 - val_sparse_categorical_accuracy: 0.9612
# Epoch 137/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1223 - val_sparse_categorical_accuracy: 0.9612
# Epoch 138/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1242 - val_sparse_categorical_accuracy: 0.9598
# Epoch 139/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0748 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1421 - val_sparse_categorical_accuracy: 0.9542
# Epoch 140/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0783 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1472 - val_sparse_categorical_accuracy: 0.9431
# Epoch 141/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1275 - val_sparse_categorical_accuracy: 0.9598
# Epoch 142/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1247 - val_sparse_categorical_accuracy: 0.9487
# Epoch 143/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1119 - val_sparse_categorical_accuracy: 0.9542
# Epoch 144/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.7660 - val_sparse_categorical_accuracy: 0.7046
# Epoch 145/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.7285 - val_sparse_categorical_accuracy: 0.7379
# Epoch 146/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.2607 - val_sparse_categorical_accuracy: 0.9154
# Epoch 147/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.6303 - val_sparse_categorical_accuracy: 0.7601
# Epoch 148/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1696 - val_sparse_categorical_accuracy: 0.9473
# Epoch 149/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1794 - val_sparse_categorical_accuracy: 0.9390
# Epoch 150/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1544 - val_sparse_categorical_accuracy: 0.9487
# Epoch 151/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0761 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1103 - val_sparse_categorical_accuracy: 0.9598
# Epoch 152/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1214 - val_sparse_categorical_accuracy: 0.9653
# Epoch 153/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1206 - val_sparse_categorical_accuracy: 0.9612
# Epoch 154/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1334 - val_sparse_categorical_accuracy: 0.9556
# Epoch 155/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1221 - val_sparse_categorical_accuracy: 0.9598
# Epoch 156/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1261 - val_sparse_categorical_accuracy: 0.9626
# Epoch 157/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0775 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1641 - val_sparse_categorical_accuracy: 0.9445
# Epoch 158/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1064 - val_sparse_categorical_accuracy: 0.9626
# Epoch 159/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0710 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1087 - val_sparse_categorical_accuracy: 0.9626
# Epoch 160/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1185 - val_sparse_categorical_accuracy: 0.9598
# Epoch 161/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0755 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1475 - val_sparse_categorical_accuracy: 0.9542
# Epoch 162/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0735 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1434 - val_sparse_categorical_accuracy: 0.9528
# Epoch 163/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1376 - val_sparse_categorical_accuracy: 0.9570
# Epoch 164/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0761 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1404 - val_sparse_categorical_accuracy: 0.9584
# Epoch 165/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 0.9556
# Epoch 166/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0686 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1484 - val_sparse_categorical_accuracy: 0.9528
# Epoch 167/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1090 - val_sparse_categorical_accuracy: 0.9570
# Epoch 168/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.1116 - val_sparse_categorical_accuracy: 0.9612
# Epoch 169/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0759 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1257 - val_sparse_categorical_accuracy: 0.9501
# Epoch 170/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0741 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1133 - val_sparse_categorical_accuracy: 0.9598
# Epoch 171/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1709 - val_sparse_categorical_accuracy: 0.9404
# Epoch 172/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1915 - val_sparse_categorical_accuracy: 0.9376
# Epoch 173/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0708 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1087 - val_sparse_categorical_accuracy: 0.9626
# Epoch 174/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1110 - val_sparse_categorical_accuracy: 0.9639
# Epoch 175/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9639
# Epoch 176/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0744 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1415 - val_sparse_categorical_accuracy: 0.9542
# Epoch 177/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1691 - val_sparse_categorical_accuracy: 0.9445
# Epoch 178/500
# 90/90 [==============================] - 7s 79ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1637 - val_sparse_categorical_accuracy: 0.9473
# Epoch 179/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1490 - val_sparse_categorical_accuracy: 0.9501
# Epoch 180/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1061 - val_sparse_categorical_accuracy: 0.9598
# Epoch 181/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9626
# Epoch 182/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1342 - val_sparse_categorical_accuracy: 0.9556
# Epoch 183/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0685 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1304 - val_sparse_categorical_accuracy: 0.9584
# Epoch 184/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1070 - val_sparse_categorical_accuracy: 0.9626
# Epoch 185/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1095 - val_sparse_categorical_accuracy: 0.9598
# Epoch 186/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0737 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1056 - val_sparse_categorical_accuracy: 0.9584
# Epoch 187/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1159 - val_sparse_categorical_accuracy: 0.9501
# Epoch 188/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1153 - val_sparse_categorical_accuracy: 0.9639
# Epoch 189/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0658 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9626
# Epoch 190/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1228 - val_sparse_categorical_accuracy: 0.9515
# Epoch 191/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1170 - val_sparse_categorical_accuracy: 0.9528
# Epoch 192/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0651 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1079 - val_sparse_categorical_accuracy: 0.9598
# Epoch 193/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1118 - val_sparse_categorical_accuracy: 0.9639
# Epoch 194/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1241 - val_sparse_categorical_accuracy: 0.9598
# Epoch 195/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1238 - val_sparse_categorical_accuracy: 0.9639
# Epoch 196/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1203 - val_sparse_categorical_accuracy: 0.9612
# Epoch 197/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1188 - val_sparse_categorical_accuracy: 0.9639
# Epoch 198/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1137 - val_sparse_categorical_accuracy: 0.9626
# Epoch 199/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1169 - val_sparse_categorical_accuracy: 0.9626
# Epoch 200/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9570
# Epoch 201/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1130 - val_sparse_categorical_accuracy: 0.9556
# Epoch 202/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1171 - val_sparse_categorical_accuracy: 0.9626
# Epoch 203/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0650 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1097 - val_sparse_categorical_accuracy: 0.9584
# Epoch 204/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0720 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1086 - val_sparse_categorical_accuracy: 0.9584
# Epoch 205/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1333 - val_sparse_categorical_accuracy: 0.9570
# Epoch 206/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1133 - val_sparse_categorical_accuracy: 0.9515
# Epoch 207/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1128 - val_sparse_categorical_accuracy: 0.9612
# Epoch 208/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1879 - val_sparse_categorical_accuracy: 0.9362
# Epoch 209/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1456 - val_sparse_categorical_accuracy: 0.9556
# Epoch 210/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1039 - val_sparse_categorical_accuracy: 0.9612
# Epoch 211/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1357 - val_sparse_categorical_accuracy: 0.9556
# Epoch 212/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1270 - val_sparse_categorical_accuracy: 0.9626
# Epoch 213/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0643 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1143 - val_sparse_categorical_accuracy: 0.9515
# Epoch 214/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0645 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1084 - val_sparse_categorical_accuracy: 0.9626
# Epoch 215/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0607 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1477 - val_sparse_categorical_accuracy: 0.9515
# Epoch 216/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1248 - val_sparse_categorical_accuracy: 0.9612
# Epoch 217/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1368 - val_sparse_categorical_accuracy: 0.9570
# Epoch 218/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0658 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1858 - val_sparse_categorical_accuracy: 0.9376
# Epoch 219/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.1154 - val_sparse_categorical_accuracy: 0.9639
# Epoch 220/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1226 - val_sparse_categorical_accuracy: 0.9639
# Epoch 221/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9639
# Epoch 222/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1425 - val_sparse_categorical_accuracy: 0.9417
# Epoch 223/500
# 90/90 [==============================] - 7s 80ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1220 - val_sparse_categorical_accuracy: 0.9487
# Epoch 224/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0662 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1252 - val_sparse_categorical_accuracy: 0.9612
# Epoch 225/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9626
# Epoch 226/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1232 - val_sparse_categorical_accuracy: 0.9612
# Epoch 227/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0626 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1722 - val_sparse_categorical_accuracy: 0.9445
# Epoch 228/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1246 - val_sparse_categorical_accuracy: 0.9584
# Epoch 229/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0644 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1184 - val_sparse_categorical_accuracy: 0.9612
# Epoch 230/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0698 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1307 - val_sparse_categorical_accuracy: 0.9598
# Epoch 231/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0672 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1084 - val_sparse_categorical_accuracy: 0.9639
# Epoch 232/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1989 - val_sparse_categorical_accuracy: 0.9334
# Epoch 233/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1158 - val_sparse_categorical_accuracy: 0.9626
# Epoch 234/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1078 - val_sparse_categorical_accuracy: 0.9612
# Epoch 235/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1283 - val_sparse_categorical_accuracy: 0.9417
# Epoch 236/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0616 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1284 - val_sparse_categorical_accuracy: 0.9459
# Epoch 237/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1143 - val_sparse_categorical_accuracy: 0.9612
# Epoch 238/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1689 - val_sparse_categorical_accuracy: 0.9445
# Epoch 239/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1374 - val_sparse_categorical_accuracy: 0.9570
# Epoch 240/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1175 - val_sparse_categorical_accuracy: 0.9626
# Epoch 241/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1184 - val_sparse_categorical_accuracy: 0.9501
# Epoch 242/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.1290 - val_sparse_categorical_accuracy: 0.9487
# Epoch 243/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0640 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1254 - val_sparse_categorical_accuracy: 0.9459
# Epoch 244/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9653
# Epoch 245/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0633 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1237 - val_sparse_categorical_accuracy: 0.9584
# Epoch 246/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1040 - val_sparse_categorical_accuracy: 0.9639
# Epoch 247/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1050 - val_sparse_categorical_accuracy: 0.9639
# Epoch 248/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9570
# Epoch 249/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1481 - val_sparse_categorical_accuracy: 0.9473
# Epoch 250/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.2515 - val_sparse_categorical_accuracy: 0.9168
# Epoch 251/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0643 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1080 - val_sparse_categorical_accuracy: 0.9653
# Epoch 252/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9639
# Epoch 253/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1192 - val_sparse_categorical_accuracy: 0.9626
# Epoch 254/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9626
# Epoch 255/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.1134 - val_sparse_categorical_accuracy: 0.9626
# Epoch 256/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1382 - val_sparse_categorical_accuracy: 0.9542
# Epoch 257/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.2387 - val_sparse_categorical_accuracy: 0.9182
# Epoch 258/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1984 - val_sparse_categorical_accuracy: 0.9348
# Epoch 259/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1153 - val_sparse_categorical_accuracy: 0.9639
# Epoch 260/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0639 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.1097 - val_sparse_categorical_accuracy: 0.9584
# Epoch 261/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0640 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1417 - val_sparse_categorical_accuracy: 0.9404
# Epoch 262/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0646 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.1175 - val_sparse_categorical_accuracy: 0.9626
# Epoch 263/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1800 - val_sparse_categorical_accuracy: 0.9362
# Epoch 264/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1321 - val_sparse_categorical_accuracy: 0.9445
# Epoch 265/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.2589 - val_sparse_categorical_accuracy: 0.9043
# Epoch 266/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1143 - val_sparse_categorical_accuracy: 0.9626
# Epoch 267/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1053 - val_sparse_categorical_accuracy: 0.9598
# Epoch 268/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0641 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1142 - val_sparse_categorical_accuracy: 0.9626
# Epoch 269/500
# 90/90 [==============================] - 7s 82ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1170 - val_sparse_categorical_accuracy: 0.9501
# Epoch 270/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0615 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1340 - val_sparse_categorical_accuracy: 0.9570
# Epoch 271/500
# 90/90 [==============================] - 7s 81ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1167 - val_sparse_categorical_accuracy: 0.9653
# Epoch 00271: early stopping

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 1s 17ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9689
# Test accuracy 0.9689394235610962
# Test loss 0.10335951298475266

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
# accuracy will start decreasing while the training accuracy will continue on increasing:
# the model starts overfitting.
